# %%
from datasets import load_dataset

dataset = load_dataset(
    "race",
    "all",
    download_mode="force_redownload"
)
# Out:
# ...
# Generating validation split: 100%|██████████| 4887/4887 [00:00<00:00, 207209.35 examples/s]

# %%
from datasets import load_dataset

dataset = load_dataset("race", "all")

base_path = r"E:\Uni Stuff\Semester_06\AI_lab\Project\RACE_Project\data\raw"

dataset["train"].to_csv(f"{base_path}\\train.csv")
dataset["test"].to_csv(f"{base_path}\\test.csv")
dataset["validation"].to_csv(f"{base_path}\\validation.csv")
# Out:
# ...
# Creating CSV from Arrow format: 100%|██████████| 5/5 [00:00<00:00, 12.29ba/s]
# 8617293
